# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
github_url = 'https://raw.githubusercontent.com/JPDVP/DV_IMS_2019/master/'
summary_file = 'dataset_files/Crimes_Summary.csv'
year_summary = 'dataset_files/{year}/Crimes_Summary_{year}.csv'
year_detail = 'dataset_files/{year}/Crimes_{year}_{ca}.csv'

# %%
def timeline_chart(df):
    data = [
        dict(type='scatter',
             y=df.loc[df['continent'] == continent]['CO2_emissions'],
             x=df.loc[df['continent'] == continent]['year'],
             text=df.loc[df['continent'] == continent]['country_name'],
             mode='markers',
             name=continent) 
        for continent in df['continent'].unique()
    ]

# %%
df = pd.read_csv(github_url + summary_file)

# %%
df.set_index(['Year','Month'], inplace=True)
df.sort_index(inplace=True)
df = df[df.index.get_level_values('Year') > 2002]

# %%
df['yyyy-mm'] = list(map(lambda index: str(index[0]) + '-' + ('00' + str(index[1]))[-2:], df.index.values))

# %%
df
# Out:
#                  Primary Type  Community Area  Arrest  Count  yyyy-mm
# Year Month
# 2003 1                  ARSON               1   False      2  2003-01
#      1                  ARSON              10    True      1  2003-01
#      1                  ARSON              13   False      2  2003-01
#      1                  ARSON              15   False      1  2003-01
#      1                  ARSON              16   False      2  2003-01
# ...                       ...             ...     ...    ...      ...
# 2019 12     WEAPONS VIOLATION              74    True      1  2019-12
#      12     WEAPONS VIOLATION              75   False      1  2019-12
#      12     WEAPONS VIOLATION              75    True      2  2019-12
#      12     WEAPONS VIOLATION               8   False      1  2019-12
#      12     WEAPONS VIOLATION               8    True      7  2019-12
#
# [410173 rows x 5 columns]

# %%
timeline_df = df.groupby(['yyyy-mm','Primary Type'])['Count'].sum().to_frame().reset_index().pivot(index='yyyy-mm', columns='Primary Type', values='Count')

# %%
data = [dict(type='scatter',x=timeline_df.index, y=timeline_df[col], name=col, marker='marker') for col in timeline_df.columns]
layout = go.Layout(
    #paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)'
)

# %%
fig = go.Figure(data=data, layout=layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-c37cb2c4fbab> in <module>
# ----> 1 fig = go.Figure(data=data, layout=layout)
#
# ~\.conda\envs\IMS_DV\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     609             is invalid AND skip_invalid is False
#     610         """
# --> 611         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     612
#     613     def add_area(
#
# ~\.conda\envs\IMS_DV\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     155
#     156         # ### Import traces ###
# --> 157         data = self._data_validator.validate_coerce(data, skip_invalid=skip_invalid)
#     158
#     159         # ### Save tuple of trace objects ###
#
# ...

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="00d869ee-f381-4056-be50-f08436dea5fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("00d869ee-f381-4056-be50-f08436dea5fb")) {
#                     Plotly.newPlot(
#                         '00d869ee-f381-4056-be50-f08436dea5fb',
# ...

# %%
timeline_series = df.groupby('yyyy-mm')['Count'].sum()

# %%
data_series =  [dict(type='scatter',x=timeline_series.index, y=timeline_series.values)]

# %%
fig_timeline = go.Figure(data=data_series)
fig_timeline.show()
# Out:
# <div>
#
#
#             <div id="b25905f4-f602-4fd7-9308-ce90464d2f6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b25905f4-f602-4fd7-9308-ce90464d2f6d")) {
#                     Plotly.newPlot(
#                         'b25905f4-f602-4fd7-9308-ce90464d2f6d',
# ...

# %%
def timeline_chart(df, cols=None, top=5, years=[], months=[]):

    df_filter = df
    if years != []: df_filter = df_filter[df_filter.index.isin(years, level=0)]
    if months != []: df_filter = df_filter[df_filter.index.isin(months, level=1)]
    
    top_types = df_filter.groupby(['Primary Type'])['Count'].sum().nlargest(top).index
    top_df = df_filter[df_filter['Primary Type'].isin(top_types)]
    pivot_df = top_df.groupby(['yyyy-mm','Primary Type'])['Count'] \
                    .sum() \
                    .to_frame() \
                    .reset_index() \
                    .pivot(index='yyyy-mm', columns='Primary Type', values='Count')
    
    return pivot_df

# %%
test_df = timeline_chart(df, top=3, years=[2014,2016])
test_df.head()

test_data = [
    dict(
        type='scatter',
        x=test_df.index,
        y=test_df[col],
        name=col
    )
    for col in test_df.columns
]

test_layout = go.Layout(
    xaxis=dict(
        tickformatstops=[
            dict(dtickrange=[None, "M12"], value='%Y-%b'),
            dict(dtickrange=["M12", None], value='%Y')
        ]
    )
)

test_fig = go.Figure(data=test_data, layout=test_layout)
test_fig.show()
# Out:
# <div>
#
#
#             <div id="e57e7df9-1ff6-40a9-9855-cf9338613963" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e57e7df9-1ff6-40a9-9855-cf9338613963")) {
#                     Plotly.newPlot(
#                         'e57e7df9-1ff6-40a9-9855-cf9338613963',
# ...

# %%
p = df.groupby(['Primary Type'])['Count'].sum().sort_values(ascending=False)[:7].index
s = df[df['Primary Type'].isin(p)].groupby(['Primary Type', 'Community Area'])['Count'].sum()

# %%
s.index.get_level_values('Primary Type')
# Out:
# Index(['ASSAULT', 'ASSAULT', 'ASSAULT', 'ASSAULT', 'ASSAULT', 'ASSAULT',
#        'ASSAULT', 'ASSAULT', 'ASSAULT', 'ASSAULT',
#        ...
#        'THEFT', 'THEFT', 'THEFT', 'THEFT', 'THEFT', 'THEFT', 'THEFT', 'THEFT',
#        'THEFT', 'THEFT'],
#       dtype='object', name='Primary Type', length=545)

# %%
sun_dict = {ptype:[ca for ca in s.loc[ptype].sort_values(ascending=False).index[:5]] for ptype in s.index.get_level_values('Primary Type').unique()}
sun_dict
# Out:
# {'ASSAULT': [25, 43, 67, 71, 68],
#  'BATTERY': [25, 43, 67, 68, 29],
#  'BURGLARY': [43, 25, 24, 71, 66],
#  'CRIMINAL DAMAGE': [25, 43, 24, 67, 49],
#  'NARCOTICS': [25, 23, 29, 26, 27],
#  'OTHER OFFENSE': [25, 43, 71, 49, 23],
#  'THEFT': [8, 32, 28, 24, 25]}

# %%
import plotly.express as px

# %%
df_sun = df[(df['Primary Type']).isin(sun_dict.keys())]


fig = px.sunburst(df_sun, path=['Arrest', 'Primary Type', 'Community Area'], values='Count')

fig.show()
# Out:
# <div>
#
#
#             <div id="92967a25-4070-4236-955e-27f3065d3a77" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("92967a25-4070-4236-955e-27f3065d3a77")) {
#                     Plotly.newPlot(
#                         '92967a25-4070-4236-955e-27f3065d3a77',
# ...

# %%
test_s = df.groupby(['Primary Type', 'Community Area'])['Count'].sum()
res = test_s.groupby(level=[0,1]).nlargest(5)

# %%
res.head(30)
# Out:
# Primary Type  Community Area
# ARSON         1                  84
#               2                  96
#               3                  68
#               4                  32
#               5                  43
#               6                  88
#               7                  50
#               8                  61
#               9                  12
#               10                 40
#               11                 34
#               12                  8
#               13                 35
#               14                 94
#               15                148
#               16                140
#               17                 69
#               18                 30
#               19                346
#               20                144
#               21                139
#               22                266
#               23                426
#               24                277
#               25                636
# ...

# %%
df['Primary Type'].groupby(df['Community Area']).value_counts().groupby(level=[0,1]).nlargest(1)
# Out:
# Community Area  Primary Type
# 0               THEFT                                15
#                 CRIMINAL DAMAGE                      14
#                 BATTERY                              13
#                 DECEPTIVE PRACTICE                   12
#                 OTHER OFFENSE                        10
#                                                      ..
# 77              CRIMINAL SEXUAL ASSAULT               4
#                 NON-CRIMINAL                          2
#                 PUBLIC INDECENCY                      2
#                 CONCEALED CARRY LICENSE VIOLATION     1
#                 OTHER NARCOTIC VIOLATION              1
# Name: Primary Type, Length: 2366, dtype: int64

# %%
s = df['Primary Type'].groupby(df['Community Area']).value_counts()

# %%
s = df.groupby(['Primary Type', 'Community Area'])['Count'].sum()
s.groupby(level=[0]).nlargest(3)
# Out:
# Primary Type       Primary Type       Community Area
# ARSON              ARSON              25                  636
#                                       23                  426
#                                       67                  383
# ASSAULT            ASSAULT            25                23555
#                                       43                14324
#                                                         ...
# THEFT              THEFT              32                77547
#                                       28                60121
# WEAPONS VIOLATION  WEAPONS VIOLATION  25                 5447
#                                       67                 3788
#                                       68                 3162
# Name: Count, Length: 105, dtype: int64

# %%
s.groupby(level=0).nlargest(2)
# Out:
# Primary Type       Primary Type       Community Area
# ARSON              ARSON              25                  636
#                                       23                  426
# ASSAULT            ASSAULT            25                23555
#                                       43                14324
# BATTERY            BATTERY            25                77227
#                                                         ...
# STALKING           STALKING           44                  117
# THEFT              THEFT              8                 88662
#                                       32                77547
# WEAPONS VIOLATION  WEAPONS VIOLATION  25                 5447
#                                       67                 3788
# Name: Count, Length: 70, dtype: int64
